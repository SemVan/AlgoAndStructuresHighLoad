# %%
import time
import random

FILE_NAME = "server_logs.txt"
TOTAL_LINES = 1_000_000

def generate_huge_log():
    """Создаем файл логов на 1 миллион строк."""
    print(f"Генерация {TOTAL_LINES} строк логов (подождите пару секунд)...")
    statuses = ["INFO: All systems operational.", "WARN: CPU load is 75%.", "DEBUG: Connection established."]
    
    with open(FILE_NAME, "w") as f:
        for i in range(TOTAL_LINES):
            # Вставляем "иголку в стог сена" где-то в самом конце
            if i == 950_000:
                f.write(f"[{i}] FATAL: database_melted_down_completely\n")
            else:
                f.write(f"[{i}] {random.choice(statuses)}\n")
    print("Файл логов готов!\n")

def test_full_table_scan():
    """Сценарий 1: Классический поиск"""
    print("Full Table Scan (Полное сканирование)")
    start_time = time.time()
    
    found_lines = []
    with open(FILE_NAME, "r") as f:
        for line in f:
            if "melted" in line:
                found_lines.append(line.strip())
                
    elapsed = time.time() - start_time
    print(f"Найдено: {found_lines}")
    print(f"Время поиска: {elapsed:.4f} секунд\n")
    return elapsed

def test_inverted_index():
    """Поиск через Инвертированный Индекс (Как Elasticsearch)"""
    print("---Inverted Index (Elasticsearch/Lucene) ---")
    
    # 1. Фаза Индексации (Делается ЗАРАНЕЕ, в фоне)
    print("[Фон] Строим инвертированный индекс в памяти...")
    inverted_index = {}
    with open(FILE_NAME, "r") as f:
        for line_num, line in enumerate(f):
            # Если видим критическое слово, сохраняем номер строки
            if "melted" in line:
                if "melted" not in inverted_index:
                    inverted_index["melted"] = []
                inverted_index["melted"].append(line_num)
                
    # 2. Фаза Поиска (То, что просит пользователь)
    print("Индекс построен. Пользователь вбивает 'melted'...")
    start_time = time.time()
    
    result_line_numbers = inverted_index.get("melted", [])
    
    elapsed = time.time() - start_time
    print(f"Найдено в строках: {result_line_numbers}")
    print(f"Время поиска: {elapsed:.6f} секунд (Внимание на нули!)")
    return elapsed

if __name__ == "__main__":
    generate_huge_log()
    t1 = test_full_table_scan()
    t2 = test_inverted_index()
    
    print("-" * 40)
    print(f"ИТОГ: Инвертированный индекс быстрее в {t1 / t2:,.0f} раз!")
# Out:
# Генерация 1000000 строк логов (подождите пару секунд)...
# Файл логов готов!
#
# Full Table Scan (Полное сканирование)
# Найдено: ['[950000] FATAL: database_melted_down_completely']
# Время поиска: 0.0533 секунд
#
# ---Inverted Index (Elasticsearch/Lucene) ---
# [Фон] Строим инвертированный индекс в памяти...
# Индекс построен. Пользователь вбивает 'melted'...
# Найдено в строках: [950000]
# Время поиска: 0.000000 секунд (Внимание на нули!)
# ----------------------------------------
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 69
#      66 t2 = test_inverted_index()
#      68 print("-" * 40)
# ---> 69 print(f"ИТОГ: Инвертированный индекс быстрее в {t1 / t2:,.0f} раз!")
#
# ZeroDivisionError: float division by zero
