# %%
import hashlib

class BloomFilterDemo:
    def __init__(self, size=15, num_hashes=2):
        """
        size - размер битового массива (делаем маленьким, чтобы поместился на экран)
        num_hashes - количество хеш-функций
        """
        self.size = size
        self.num_hashes = num_hashes
        self.bit_array = [0] * size

    def _get_hashes(self, item):
        """превращает строку в список индексов (от 0 до size-1)"""
        indices = []
        for i in range(self.num_hashes):
            # солим строку, чтобы получить разные хеши (например: "Alice:0", "Alice:1")
            salted_item = f"{item}:{i}"
            # Получаем MD5 и берем остаток от деления на размер массива
            hash_int = int(hashlib.md5(salted_item.encode()).hexdigest(), 16)
            indices.append(hash_int % self.size)
        return indices

    def add(self, item):
        """Заносит элемент в фильтр (ставит единички)"""
        indices = self._get_hashes(item)
        for idx in indices:
            self.bit_array[idx] = 1

    def check(self, item):
        """Проверяет наличие элемента"""
        indices = self._get_hashes(item)
        
        for idx in indices:
            bit_value = self.bit_array[idx]
            print(f" -> Проверяем бит {idx}: {bit_value}")
            if bit_value == 0:
                print(f" -> РЕЗУЛЬТАТ: Бит равен 0. Элемента '{item}' ТОЧНО НЕТ.")
                return False
                
        print(f" -> РЕЗУЛЬТАТ: Все нужные биты равны 1. Элемент '{item}', ВОЗМОЖНО, ЕСТЬ.")
        return True


if __name__ == "__main__":
    # Создаем маленький фильтр, чтобы быстро его "засорить" единицами
    filter = BloomFilterDemo(size=14, num_hashes=2)
    
    # 1. Заполняем фильтр реальными пользователями
    filter.add("Alice")
    filter.add("Bob")
    filter.add("Charlie")
    
    print("="*40)
    
    # 2. Проверяем того, кто ТОЧНО ЕСТЬ (Ожидаем True)
    filter.check("Alice")
    
    print("-" * 40)
    
    # Проверяем того, кого ТОЧНО НЕТ (Ожидаем False)
    # Зная алгоритм, слово "Dave" попадет на нули
    filter.check("Dave")
    
    print("пробуем ложное срабатывание")
    
    #будем проверять случайные имена, пока биты случайно не совпадут!
    test_names = ["Eve", "Frank", "Grace", "Heidi", "Ivan", "Judy", "Kevin"]
    
    for name in test_names:
        print(f"\nТестируем '{name}':")
        # Если класс вернул True, хотя мы не делали add() - считаем, что возможно ключ есть
        if filter.check(name):
            print(f"\n ложное срабатывание ")
            print(f"мы никогда не добавляли '{name}' в базу!")
            print(f"но хеши слова '{name}' случайно попали на те единички,")
            print(f"которые до этого оставили Alex, Bob и Charlie.")
            print(f"Текущий массив: {filter.bit_array}")
            break
# Out:
# ========================================
#  -> Проверяем бит 0: 1
#  -> Проверяем бит 6: 1
#  -> РЕЗУЛЬТАТ: Все нужные биты равны 1. Элемент 'Alice', ВОЗМОЖНО, ЕСТЬ.
# ----------------------------------------
#  -> Проверяем бит 8: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Dave' ТОЧНО НЕТ.
# пробуем ложное срабатывание
#
# Тестируем 'Eve':
#  -> Проверяем бит 10: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Eve' ТОЧНО НЕТ.
#
# Тестируем 'Frank':
#  -> Проверяем бит 7: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Frank' ТОЧНО НЕТ.
#
# Тестируем 'Grace':
#  -> Проверяем бит 3: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Grace' ТОЧНО НЕТ.
#
# Тестируем 'Heidi':
#  -> Проверяем бит 5: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Heidi' ТОЧНО НЕТ.
#
# Тестируем 'Ivan':
#  -> Проверяем бит 2: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Ivan' ТОЧНО НЕТ.
#
# Тестируем 'Judy':
#  -> Проверяем бит 8: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Judy' ТОЧНО НЕТ.
#
# Тестируем 'Kevin':
#  -> Проверяем бит 5: 0
#  -> РЕЗУЛЬТАТ: Бит равен 0. Элемента 'Kevin' ТОЧНО НЕТ.
